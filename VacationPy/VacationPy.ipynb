# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from api_config import (google_api)

gmaps.configure(google_api)

# %%
df = pd.read_csv("weather.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        city     lon    lat  wind_speed  max_temp  humidity  \
# 0           0       Manga   -1.07  11.66        0.85     82.81        25
# 1           1    Ambilobe   49.05 -13.20        2.77     74.75        91
# 2           2   Busselton  115.33 -33.65        1.01     59.00        97
# 3           3     Sakakah   40.21  29.97       17.22     59.00        54
# 4           4  Gold Coast  153.43 -28.00       16.11     80.01        50
#
#          date country  cloud
# 0  1584494069      BF     40
# 1  1584494070      MG     47
# 2  1584493781      AU     20
# 3  1584494070      SA      0
# 4  1584493930      AU      4

# %%
locations = df[["lat", "lon"]].astype(float)
humidity = df['humidity'].astype(float)

# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df_temp = df[(df.max_temp > 78)]
df_temp

df_temp2 = df_temp[(df_temp.max_temp < 85)]
df_temp2

df_wind = df_temp2[(df_temp2.wind_speed < 5)]
df_wind

df_cloud = df_wind[(df_wind.cloud == 0)]
df_cloud
# Out:
#      Unnamed: 0          city    lon    lat  wind_speed  max_temp  humidity  \
# 169         169   Youkounkoun -13.13  12.53        2.13     79.18        15
# 338         338  Quatre Cocos  57.76 -20.21        3.80     78.78        77
# 510         510  Sharjah city  55.40  25.36        2.24     78.01        72
#
#            date country  cloud
# 169  1584494115      GN      0
# 338  1584493955      MU      0
# 510  1584494200      AE      0

# %%
locations = df_cloud[["lat", "lon"]].astype(float)

# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations = df_cloud[["lat", "lon"]].astype(float)

# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations)
# Add the layer to the map
fig.add_layer(markers)
fig

list_of_infoboxes = [
        'Hotel Name: Hotel Badiar'
        'City: Sambailo'
        'Country: Guinea'
    ]

list_of_infoboxes2 = [
        'Hotel Name: Shangri-Las Le Touessrok Resort & Spa'
        'City: Coastal Road'
        'Country: Mauritus'
    ]

list_of_infoboxes3 = [
        'Hotel Name: Alantos Žirgai'
        'City: Utenos g. 9'
        'Country: Lithuania'
    ]

# %%
# geocoordinates
target_coordinates = "12.53, -13.13"
target_search = "Hotel"
target_radius = 28000
target_type = "Hotel"

# %%
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": google_api
}

# %%
# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 12.5793372,
#                     "lng": -13.3714446
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 12.58074302989272,
#                         "lng": -13.36992842010728
#                     },
#                     "southwest": {
#                         "lat": 12.57804337010728,
#                         "lng": -13.37262807989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3edec0885bc7e8231f574ab6c65be86d3a03eab1",
#             "name": "Hotel Badiar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJkxHHeTDR-g4RevM4OxJY8Jk",
#             "plus_code": {
# ...

# %%
# Print closest hotel
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Hotel Badiar
# Sambailo

# %%
# geocoordinates
target_coordinates = "-20.21, 57.76"
target_search = "Hotel"
target_radius = 5000
target_type = "Hotel"

# %%
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": google_api
}

# %%
# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCIQEAAO0Pub1UA3S_aR3KY9_9VEUjqQJaA4D1y63ecek5evO4FDQ50Ka-FS7A8Md1aQU18AdZFVFE1ncn84MtWgD3A3EfNgu0o6759VIQNCg4KzdJdxbr8QkY6_bGaqwxEN1LArSaQbHrGgcOweEruERJ2V5lM49aZuarn0NvsoIC8xcyhRhBcQsvxwUp1vVdNYzyDrnwEGfzcB_s2h3x0Rur3JCRnP49rD_oD-icPJmzzxurtVFPZOyjgcxXBKpCTusyenziDglWNTlfQth09WnVk4kozYm7bltWF0nBXAABTPR1dsrWFSBslTZTOR-261TZvspihzpQfYloicArZh80Xgndj9NvPJ4cIiywaFWhBGN9lixyauvXMsiQNppTsNiJMbscneXpyxOV_Rh0vxdNi1USEG1eJe6NjLVXx2m-4y5w7QEaFFn8vBjqP8KMoRNiBgS_Kdc3VA8-",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -20.1990171,
#                     "lng": 57.78234980000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.19809207010728,
#                         "lng": 57.78311947989273
#                     },
#                     "southwest": {
# ...

# %%
# Print closest hotel
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# LUX Belle Mare Resort & Villas
# Coastal Road

# %%
# geocoordinates
target_coordinates = "55.40, 25.36"
target_search = "Hotel"
target_radius = 5000
target_type = "Hotel"

# %%
# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": google_api
}

# %%
# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 55.3603287,
#                     "lng": 25.3002798
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 55.36170257989271,
#                         "lng": 25.30154607989272
#                     },
#                     "southwest": {
#                         "lat": 55.35900292010727,
#                         "lng": 25.29884642010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "aed4307c6134c495dbe3431f5852dcdaa687557c",
#             "name": "Alantos \u017dirgai",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
# ...

# %%
# Print closest hotel
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Alantos Žirgai
# Utenos g. 9, Kazlų km, Alanta
